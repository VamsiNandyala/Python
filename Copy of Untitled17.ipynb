# %%
def atm():
  def __init__(self,enter_pin,balance,deposit,withdraw):
    self.enter_pin=enter_pin
    self.check_balance=check_balance
    self.deposit=deposit
    self.withdraw=withdraw
  def enter_pin1(self):
      print(self.enter_pin)
  def check_balance2(self):
      print(self.check_balance)
  def deposit3(self,deposit):
      self.balance+=deposit
  def withdraw4(self):
      print(self.withdraw)
enter_pin1=int(input("enter a number"))
balance2=int(input("enter a balance"))
deposit3=int(input("enter a deposit money"))
withdraw4=int(input("enter a withdraw"))
obj1=atm(enter_pin1,balance2,deposit3,withdraw4)
# Out:
# enter a number0000
# enter a balance6000
# enter a deposit money4000
# enter a withdraw5000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f0faed46dc6d> in <cell line: 19>()
#      17 deposit3=int(input("enter a deposit money"))
#      18 withdraw4=int(input("enter a withdraw"))
# ---> 19 obj1=atm(enter_pin1,balance2,deposit3,withdraw4)
#
# TypeError: atm() takes 0 positional arguments but 4 were given

# %%
hujhjh
