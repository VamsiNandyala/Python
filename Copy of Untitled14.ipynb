# %%
#write
file = open('iot.txt','w')
file.write('python \n java \n html')
file.close()

# %%
#read
file = open('iot.txt')
data = file.read()
print(data)
file.close()
# Out:
# python
#  java
#  html

# %%
a=map(lambda a:a+3,[1,2,3])
print(a)
print(set(a))
# Out:
# ...
# {4, 5, 6}

# %%
a=int(input("enter a no of working days "))
b=int(input("enter a no of working days "))
c=int(input("enter a no of working days "))
salary=int(input("per month salary "))
per_day_salary=salary/30
salary_of_a=a*per_day_salary
salary_of_b=b*per_day_salary
salary_of_c=c*per_day_salary
print("A: "+ str(salary_of_a``))
print("B: "+ str(salary_of_b))
print("C: "+ str(salary_of_c))
# Out:
# enter a no of working days 30
# enter a no of working days 25
# enter a no of working days 20
# per month salary 25000
# A: 25000.0
# B: 20833.333333333336
# C: 16666.666666666668

# %%
import pickle
mylist = ['a','b','c','d']
with open('datafile.txt','wb') as fh:
   pickle.dump(mylist,fh)

# %%
import pickle
pickle_off = open ("datafile.txt","rb")
emp = pickle.load(pickle_off)
print(emp)
# Out:
# ['a', 'b', 'c', 'd']

# %%
#reduce function in python
from functools-+--
