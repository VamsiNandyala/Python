# %%
def atm():
  def __init__(self,enter_pin,balance,deposit,withdraw):
    self.enter_pin=enter_pin
    self.check_balance=check_balance
    self.deposit=deposit
    self.withdraw=withdraw
  def enter_pin(self):
      print(self.enter_pin)
  def check_balance(self):
      print(self.check_balance)
  def deposit(self,deposit):
      self.balance+=deposit
  def withdraw(self):
      print(self.withdraw)
enter_pin=int(input("enter a number"))
balance=int(input("enter a balance"))
deposit=int(input("enter a deposit money"))
withdraw=int(input("enter a withdraw"))
obj1=atm("enter_pin","balance","deposit","withdraw")
# Out:
# enter a number0
# enter a balance2000
# enter a deposit money4000
# enter a withdraw3000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-8637deb36bee> in <cell line: 19>()
#      17 deposit=int(input("enter a deposit money"))
#      18 withdraw=int(input("enter a withdraw"))
# ---> 19 obj1=atm("enter_pin","balance","deposit","withdraw")
#
# TypeError: atm() takes 0 positional arguments but 4 were given
