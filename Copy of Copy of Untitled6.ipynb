# %%
for i in range(1,21):
        print("natural numbers",i)
# Out:
# natural numbers 1
# natural numbers 2
# natural numbers 3
# natural numbers 4
# natural numbers 5
# natural numbers 6
# natural numbers 7
# natural numbers 8
# natural numbers 9
# natural numbers 10
# natural numbers 11
# natural numbers 12
# natural numbers 13
# natural numbers 14
# natural numbers 15
# natural numbers 16
# natural numbers 17
# natural numbers 18
# natural numbers 19
# natural numbers 20

# %%
for i in range(1,20,2):
  print(i+1)
